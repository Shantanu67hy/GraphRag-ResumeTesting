# %%
# Copyright (c) 2024 Microsoft Corporation.
# Licensed under the MIT License.

# %%
import os

import pandas as pd
import tiktoken

from graphrag.config.enums import ModelType
from graphrag.config.models.language_model_config import LanguageModelConfig
from graphrag.language_model.manager import ModelManager
from graphrag.query.indexer_adapters import (
    read_indexer_communities,
    read_indexer_entities,
    read_indexer_reports,
)
from graphrag.query.structured_search.global_search.community_context import (
    GlobalCommunityContext,
)
from graphrag.query.structured_search.global_search.search import GlobalSearch

# %% [markdown]
# ## Global Search example
#
# Global search method generates answers by searching over all AI-generated community reports in a map-reduce fashion. This is a resource-intensive method, but often gives good responses for questions that require an understanding of the dataset as a whole (e.g. What are the most significant values of the herbs mentioned in this notebook?).

# %% [markdown]
# ### LLM setup

# %%
#llm_model = "gpt-4o"
config = LanguageModelConfig(
    #api_key=
    #type=ModelType.AzureOpenAIChat,
    #model=llm_model,                      
    #deployment_name=llm_model,
    #max_retries=20,
    #api_base=
    #api_version="2024-12-01-preview"
)
model = ModelManager().get_or_create_chat_model(
    #name="global_search",
    #model_type=
    #config=config,
)

token_encoder = tiktoken.encoding_for_model(llm_model)

# %% [markdown]
# ### Load community reports as context for global search
#
# - Load all community reports in the `community_reports` table from GraphRAG, to be used as context data for global search.
# - Load entities from the `entities` tables from GraphRAG, to be used for calculating community weights for context ranking. Note that this is optional (if no entities are provided, we will not calculate community weights and only use the rank attribute in the community reports table for context ranking)
# - Load all communities in the `communities` table from the GraphRAG, to be used to reconstruct the community graph hierarchy for dynamic community selection.

# %%
# parquet files generated from indexing pipeline
INPUT_DIR = r"C:\Users\v-chandanap\Desktop\GraphRAGAPI\input"


COMMUNITY_REPORT_TABLE = "community_reports"
ENTITY_TABLE = "entities"
COMMUNITY_TABLE = "communities"

COMMUNITY_LEVEL = 2

# %%
entity_df = pd.read_parquet(r'C:\Users\v-chandanap\Desktop\GraphRAGAPI\output\entities.parquet')
community_df = pd.read_parquet(r'C:\Users\v-chandanap\Desktop\GraphRAGAPI\output\communities.parquet')
report_df = pd.read_parquet(r'C:\Users\v-chandanap\Desktop\GraphRAGAPI\output\community_reports.parquet')
communities = read_indexer_communities(community_df, report_df)
reports = read_indexer_reports(report_df, community_df, COMMUNITY_LEVEL)
entities = read_indexer_entities(entity_df, community_df, COMMUNITY_LEVEL)
print(f"Total report count: {len(report_df)}")
print(
    f"Report count after filtering by community level {COMMUNITY_LEVEL}: {len(reports)}"
)

report_df.head()
# Out:
# Total report count: 12
# Report count after filtering by community level 2: 12
#                                  id  human_readable_id  community  level  \
# 0  1e420d26dd8449c893d51d7b3bf2ba43                  6          6      1
# 1  2ec6587c87d8415691eacd54494887fd                  7          7      1
# 2  41fb1bcc24934e30ac1487a33a795fc5                  8          8      1
# 3  21722383bebc4f838831cc21162e63a7                  9          9      1
# 4  4ad6ff858ac542bda74f4454732fbe48                 10         10      1
#
#    parent children                                              title  \
# 0       3       []                     Affine Employee Leave Policies
# 1       3       []  Affine's Long Leave Policy and Sabbatical Stru...
# 2       3       []       Affine Leave Management and Policy Structure
# 3       5       []            Affine Inc. and Employee Leave Policies
# 4       5       []  Affine Inc. Leave Policies and Employee Manage...
#
#                                              summary  \
# 0  The community centers around Affine, a company...
# 1  The community is centered around Affine's Long...
# 2  The community centers around Affine's leave ma...
# 3  Affine Inc., located in Bellevue, Washington, ...
# 4  The community centers around Affine Inc.'s lea...
#
#                                         full_content  rank  \
# 0  # Affine Employee Leave Policies\n\nThe commun...   6.5
# 1  # Affine's Long Leave Policy and Sabbatical St...   4.5
# 2  # Affine Leave Management and Policy Structure...   7.5
# 3  # Affine Inc. and Employee Leave Policies\n\nA...   6.5
# 4  # Affine Inc. Leave Policies and Employee Mana...   6.5
#
#                                   rating_explanation  \
# 0  The impact severity rating is moderate due to ...
# 1  The impact severity rating is moderate due to ...
# 2  The impact severity rating is high due to the ...
# 3  The impact severity rating is moderate due to ...
# 4  The impact severity rating is moderate to high...
#
#                                             findings  \
# 0  [{'explanation': 'Affine offers a wide range o...
# 1  [{'explanation': 'Affine's Long Leave Policy i...
# 2  [{'explanation': 'The Caregiver Leave policy a...
# 3  [{'explanation': 'Affine Inc. offers a wide ra...
# 4  [{'explanation': 'Affine Inc. structures its l...
#
#                                    full_content_json      period  size
# 0  {\n    "title": "Affine Employee Leave Policie...  2025-07-28     7
# 1  {\n    "title": "Affine's Long Leave Policy an...  2025-07-28     3
# 2  {\n    "title": "Affine Leave Management and P...  2025-07-28     5
# 3  {\n    "title": "Affine Inc. and Employee Leav...  2025-07-28    10
# 4  {\n    "title": "Affine Inc. Leave Policies an...  2025-07-28     3

# %% [markdown]
# #### Build global context based on community reports

# %%
context_builder = GlobalCommunityContext(
    community_reports=reports,
    communities=communities,
    entities=entities,  # default to None if you don't want to use community weights for ranking
    token_encoder=token_encoder,
)

# %% [markdown]
# #### Perform global search

# %%
context_builder_params = {
    "use_community_summary": False,  # False means using full community reports. True means using community short summaries.
    "shuffle_data": True,
    "include_community_rank": True,
    "min_community_rank": 0,
    "community_rank_name": "rank",
    "include_community_weight": True,
    "community_weight_name": "occurrence weight",
    "normalize_community_weight": True,
    "max_tokens": 12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    "context_name": "Reports",
}

map_llm_params = {
    "max_tokens": 1000,
    "temperature": 0.0,
    "response_format": {"type": "json_object"},
}

reduce_llm_params = {
    "max_tokens": 2000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000-1500)
    "temperature": 0.0,
}

# %%
search_engine = GlobalSearch(
    model=model,
    context_builder=context_builder,
    token_encoder=token_encoder,
    max_data_tokens=12_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
    map_llm_params=map_llm_params,
    reduce_llm_params=reduce_llm_params,
    allow_general_knowledge=False,  # set this to True will add instruction to encourage the LLM to incorporate general knowledge in the response, which may increase hallucinations, but could be useful in some use cases.
    json_mode=True,  # set this to False if your LLM model does not support JSON mode.
    context_builder_params=context_builder_params,
    concurrent_coroutines=32,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %%
result = await search_engine.search("What are the different types of leaves offered at Affine and their respective eligibility criteria?")

print(result.response)
# Out:
# ### Overview of Leave Policies at Affine
#
# Affine offers a comprehensive range of leave options designed to address diverse employee needs and promote a healthy work-life balance. These policies are structured around the fiscal year, which runs from April 1st to March 31st, ensuring consistency in leave calculations and grants [Data: Reports (3, 5, 6, 9, 10, +more)].
#
# Below is a detailed breakdown of the types of leaves offered and their respective eligibility criteria:
#
# ---
#
# ### **1. Earned Leaves**
# - **Eligibility**: Employees accrue earned leaves on a quarterly basis, with a maximum accumulation of 20 days per year.
# - **Usage**: These leaves must be utilized within the fiscal year to prevent accumulation beyond the annual limit [Data: Reports (0, 10)].
#
# ---
#
# ### **2. Sick and Casual Leaves**
# - **Purpose**: These leaves are intended for managing short-term health issues or personal matters.
# - **Eligibility**: Available to all employees as part of Affine's commitment to employee well-being [Data: Reports (3, 6)].
#
# ---
#
# ### **3. Public Holidays**
# - **Eligibility**: Employees are entitled to public holidays as per the company's calendar. These holidays are predefined and do not require specific criteria for eligibility [Data: Reports (3, 5, 6, 9, +more)].
#
# ---
#
# ### **4. Maternity and Paternity Leave**
# - **Maternity Leave**:
#   - **Eligibility**: Offered to female employees during childbirth and early childcare. The policy aligns with the Family and Medical Leave Act (FMLA), ensuring compliance with legal standards [Data: Reports (5, 4, 11)].
# - **Paternity Leave**:
#   - **Eligibility**: Available to male employees to promote active involvement in childcare during the early stages [Data: Reports (5, 4, 11)].
#
# ---
#
# ### **5. Caregiver Leave**
# - **Purpose**: Designed to support employees during personal challenges, such as grieving the loss of a loved one or managing caregiving responsibilities.
# - **Eligibility**: Employees may take up to ten working days off under this policy [Data: Reports (3, 8)].
#
# ---
#
# ### **6. Long Leave**
# - **Purpose**: Allows employees to take extended time off for personal growth, further education, or other pursuits.
# - **Eligibility**: Requires management approval and is contingent upon meeting specific criteria. Employees must justify the purpose of the leave and obtain prior approval [Data: Reports (3, 4, 7)].
#
# ---
#
# ### **7. Sabbatical Leave**
# - **Purpose**: Enables employees to take extended time off for personal or professional development.
# - **Eligibility**: Sabbaticals may be unpaid and require a mandatory one-year gap between sabbaticals. Approval is subject to management discretion [Data: Reports (3, 4, 7)].
#
# ---
#
# ### **8. COVID-Related Paid Time Off**
# - **Purpose**: Provides paid time off for employees who test positive for COVID-19.
# - **Eligibility**: Employees are granted up to four working days off to recover without work obligations [Data: Reports (3, 5, 10)].
#
# ---
#
# ### Commentary on Leave Structure
#
# Affine's leave policies reflect a strong commitment to employee well-being and flexibility. By offering a diverse range of leave options, the company ensures that employees can address personal, health, and professional needs effectively. The alignment of leave policies with the fiscal year further promotes clarity and consistency in their application.
#
# These policies not only comply with legal standards, such as the FMLA for maternity leave, but also go beyond statutory requirements by introducing caregiver leave and sabbatical options. This approach underscores Affine's focus on fostering a supportive and inclusive workplace environment.

# %%
# inspect the data used to build the context for the LLM responses
result.context_data["reports"]
# Out:
#     id                                              title  occurrence weight  \
# 0    3        Affine and Its Comprehensive Leave Policies               1.00
# 1    5   Affine Inc. and Its Comprehensive Leave Policies               0.90
# 2    2           Affine Leave Management and HR Structure               0.85
# 3    6                     Affine Employee Leave Policies               0.85
# 4    9            Affine Inc. and Employee Leave Policies               0.75
# 5    0             Affine Analytics and Global Operations               0.60
# 6    8       Affine Leave Management and Policy Structure               0.45
# 7    4  Affine Inc. and Affine Analytics Pvt. Ltd. Lea...               0.35
# 8   10  Affine Inc. Leave Policies and Employee Manage...               0.30
# 9    1  Affine Project Management and Delivery Coordin...               0.10
# 10   7  Affine's Long Leave Policy and Sabbatical Stru...               0.05
# 11  11              Affine Inc. Maternity Leave Community               0.05
#
#                                               content  rank
# 0   # Affine and Its Comprehensive Leave Policies\...   7.5
# 1   # Affine Inc. and Its Comprehensive Leave Poli...   7.5
# 2   # Affine Leave Management and HR Structure\n\n...   7.5
# 3   # Affine Employee Leave Policies\n\nThe commun...   6.5
# 4   # Affine Inc. and Employee Leave Policies\n\nA...   6.5
# 5   # Affine Analytics and Global Operations\n\nTh...   7.5
# 6   # Affine Leave Management and Policy Structure...   7.5
# 7   # Affine Inc. and Affine Analytics Pvt. Ltd. L...   7.5
# 8   # Affine Inc. Leave Policies and Employee Mana...   6.5
# 9   # Affine Project Management and Delivery Coord...   6.5
# 10  # Affine's Long Leave Policy and Sabbatical St...   4.5
# 11  # Affine Inc. Maternity Leave Community\n\nThe...   3.5

# %%
print(result.context_data["reports"].at[0,'content'])
# Out:
# # Affine and Its Comprehensive Leave Policies
#
# The community centers around Affine, a company dedicated to employee well-being through its comprehensive leave policies. Key entities include various leave types such as Caregiver Leave, Maternity/Paternity Leave, and COVID-related leave, all supported by Affine's HR team and management structure. The relationships between these entities highlight Affine's commitment to fostering a supportive work environment, with a focus on maintaining a healthy work-life balance for its employees.
#
# ## Affine's Commitment to Employee Well-being
#
# Affine is deeply committed to the well-being of its employees, as evidenced by its comprehensive leave policies. These policies are designed to accommodate the diverse needs of its workforce, offering a variety of leave options such as Earned Leaves, Sick and Casual Leaves, and Public Holidays. The company's structured approach ensures that employees have the necessary time off to recharge and manage personal commitments, reflecting its dedication to fostering a supportive and accommodating work environment [Data: Entities (0), Relationships (46, 47)].
#
# ## Special Leave Policies at Affine
#
# Affine has implemented several special leave policies to further support its employees. These include the Long Leave Policy, which allows employees to take extended time off for personal growth or other pursuits, and the Caregiver Leave Policy, which provides paid time off for grieving the loss of a loved one. Additionally, Affine offers COVID-related paid time off for employees who test positive, demonstrating its commitment to health and safety during the pandemic. These policies underscore Affine's dedication to employee well-being and its proactive approach to addressing the challenges posed by the global health crisis [Data: Entities (37, 22, 23); Relationships (66, 34)].
#
# ## Role of HR and Management in Leave Administration
#
# The HR team and management at Affine play crucial roles in administering the company's leave policies. The HR team is responsible for overseeing leave accounts and ensuring that employees' leave balances are accurately maintained. Managers, on the other hand, are tasked with discussing and approving leave plans, including Caregiver Leave and compensatory leave. Senior Managers or Vice Presidents are involved in approving leave extensions, ensuring that requests are thoroughly reviewed and aligned with the company's guidelines. This collaborative approach ensures that leave policies are applied fairly and consistently across the organization, contributing to employee satisfaction and operational efficiency [Data: Entities (15, 14, 25, 21); Relationships (37, 24, 64, 36)].
#
# ## GreytHR's Role in Leave Management
#
# GreytHR is a comprehensive platform utilized by Affine for various aspects of leave management and holiday declarations. It serves as a centralized portal where employees can apply for leaves, ensuring streamlined communication and record-keeping within the organization. Upon returning from caregiving leave or any other type of leave, employees are required to update their leave status through GreytHR, facilitating accurate tracking and management of leave records. This platform is integral to maintaining up-to-date leave records, which is crucial for both employees and the organization to ensure transparency and efficiency in leave management processes [Data: Entities (20); Relationships (41)].
#
# ## Impact of Affine's Leave Policies on Organizational Culture
#
# Affine's comprehensive leave policies have a significant impact on its organizational culture, promoting a healthy work-life balance and employee satisfaction. By offering a variety of leave options and special policies, Affine demonstrates its commitment to supporting its workforce in managing personal and professional needs. This approach not only enhances employee well-being but also contributes to a positive and supportive work environment, which is essential for attracting and retaining talent. The company's dedication to fostering a culture of understanding and flexibility is evident in its structured leave management system, which is designed to accommodate the diverse needs of its employees [Data: Entities (0), Relationships (66, 34, 46, 47)].

# %%
result = await search_engine.search("What is the eligibility for sabbatical leave?")

print(result.response)

# inspect the data used to build the context for the LLM responses
result.context_data["reports"]

# inspect number of LLM calls and tokens
print(
    f"LLM calls: {result.llm_calls}. Prompt tokens: {result.prompt_tokens}. Output tokens: {result.output_tokens}."
)
# Out:
# 2025-07-23 14:31:47.0677 - WARNING - graphrag.query.structured_search.global_search.search - Warning: All map responses have score 0 (i.e., no relevant information found from the dataset), returning a canned 'I do not know' answer. You can try enabling `allow_general_knowledge` to encourage the LLM to incorporate relevant general knowledge, at the risk of increasing hallucinations.
# I am sorry but I am unable to answer this question given the provided data.
# LLM calls: 1. Prompt tokens: 1670. Output tokens: 46.
